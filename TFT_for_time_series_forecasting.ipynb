# %% [markdown]
# <a href="https://colab.research.google.com/github/Bumblebee2397/Time-Series-Forecasting/blob/master/TFT_for_time_series_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Preliminary Setup**

# %% [markdown]
# ### Installing required packages

# %%
# Uses pip3 to install necessary packages
# !pip3 install pyunpack wget patool plotly cufflinks --user

# Resets the IPython kernel to import the installed package.
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# Requirement already satisfied: pyunpack in /root/.local/lib/python3.6/site-packages (0.2.1)
# Requirement already satisfied: wget in /root/.local/lib/python3.6/site-packages (3.2)
# Requirement already satisfied: patool in /root/.local/lib/python3.6/site-packages (1.12)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (4.4.1)
# Requirement already satisfied: cufflinks in /usr/local/lib/python3.6/dist-packages (0.17.3)
# Requirement already satisfied: entrypoint2 in /root/.local/lib/python3.6/site-packages (from pyunpack) (0.2.1)
# Requirement already satisfied: easyprocess in /root/.local/lib/python3.6/site-packages (from pyunpack) (0.3)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.12.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (7.5.1)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (49.1.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (5.5.0)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (1.0.5)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (1.18.5)
# Requirement already satisfied: argparse in /root/.local/lib/python3.6/site-packages (from entrypoint2->pyunpack) (1.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (4.3.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (5.0.7)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (2.1.3)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (1.0.18)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (0.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks) (2.8.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.5.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.2.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.6.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks) (0.6.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (19.0.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.2)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.1.5)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.4.7)
# {'restart': True, 'status': 'ok'}

# %%
# Changing the tensorflow version from 2.x to 1.x
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %% [markdown]
# ### Traversing to the directory containing TFT code (downloaded from Github)

# %%
# Check current directory
import os
print(os.getcwd())
# Out:
# /content

# %%
# Traverse to the directory containing TFT
os.chdir('/content/drive/My Drive/TFT for TSF/tft')

# %% [markdown]
# ### Downloading the traffic dataset

# %%
import pandas as pd
from script_download_data import main as download_data

# %%
# Download parameters
expt_name = 'traffic'                                  # Name of default experiment
output_folder = os.path.join(os.getcwd(), 'outputs')   # Root folder to save experiment outputs
force_download = False                                 # Skips download if data is already present

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Downloads main csv file if not present
csv_file = os.path.join(output_folder,'data','traffic', 'hourly_data.csv')
if not os.path.exists(csv_file):
    download_data(expt_name, force_download=True, output_folder=output_folder)

# Load the downloaded data
df = pd.read_csv(csv_file, index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# Have a look at the data
df.head(24)
# Out:
#       values  prev_values  ...  categorical_day_of_week  categorical_time_on_day
# 0   0.019333     0.020933  ...                        4                        1
# 1   0.020200     0.019333  ...                        4                        2
# 2   0.022450     0.020200  ...                        4                        3
# 3   0.029283     0.022450  ...                        4                        4
# 4   0.055483     0.029283  ...                        4                        5
# 5   0.073933     0.055483  ...                        4                        6
# 6   0.057067     0.073933  ...                        4                        7
# 7   0.059383     0.057067  ...                        4                        8
# 8   0.064050     0.059383  ...                        4                        9
# 9   0.069033     0.064050  ...                        4                       10
# 10  0.066433     0.069033  ...                        4                       11
# 11  0.066983     0.066433  ...                        4                       12
# 12  0.068933     0.066983  ...                        4                       13
# 13  0.067467     0.068933  ...                        4                       14
# 14  0.063967     0.067467  ...                        4                       15
# 15  0.061283     0.063967  ...                        4                       16
# 16  0.066200     0.061283  ...                        4                       17
# 17  0.056433     0.066200  ...                        4                       18
# 18  0.045350     0.056433  ...                        4                       19
# 19  0.038983     0.045350  ...                        4                       20
# 20  0.036283     0.038983  ...                        4                       21
# 21  0.031550     0.036283  ...                        4                       22
# 22  0.024933     0.031550  ...                        4                       23
# 23  0.023167     0.024933  ...                        5                        0
#
# [24 rows x 11 columns]

# %% [markdown]
# ### Data Definitions

# %%
from data_formatters.base import GenericDataFormatter, DataTypes, InputTypes

# View avialable inputs and data types.
print("Available data types:")
for option in DataTypes:
    print(option)

print()
print("Avaialbe input types:")
for option in InputTypes:
    print(option)
# Out:
# Available data types:
# DataTypes.REAL_VALUED
# DataTypes.CATEGORICAL
# DataTypes.DATE
#
# Avaialbe input types:
# InputTypes.TARGET
# InputTypes.OBSERVED_INPUT
# InputTypes.KNOWN_INPUT
# InputTypes.STATIC_INPUT
# InputTypes.ID
# InputTypes.TIME

# %%
from libs import utils        # Load TFT helper functions
import sklearn.preprocessing  # Used for data standardization

# Implement formatting functions
class TrafficFormatter(GenericDataFormatter):
    """Defines and formats data for the traffic dataset.

    This also performs z-score normalization across the entire dataset, hence
    re-uses most of the same functions as volatility.

    Attributes:
    column_definition: Defines input and data type of column used in the
      experiment.
    identifiers: Entity identifiers used in experiments.
    """
    
    # This defines the types used by each column
    _column_definition = [
      ('id', DataTypes.REAL_VALUED, InputTypes.ID),   
      ('hours_from_start', DataTypes.REAL_VALUED, InputTypes.TIME),
      ('values', DataTypes.REAL_VALUED, InputTypes.TARGET),
      ('time_on_day', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
      ('day_of_week', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
      ('hours_from_start', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
      ('categorical_id', DataTypes.CATEGORICAL, InputTypes.STATIC_INPUT),
    ]

    def split_data(self, df, valid_boundary=151, test_boundary=166):
        """Splits data frame into training-validation-test data frames.

        This also calibrates scaling object, and transforms data for each split.

        Args:
          df: Source data frame to split.
          valid_boundary: Starting year for validation data
          test_boundary: Starting year for test data

        Returns:
          Tuple of transformed (train, valid, test) data.
        """

        print('Formatting train-valid-test splits.')

        index = df['sensor_day']
        train = df.loc[index < valid_boundary]
        valid = df.loc[(index >= valid_boundary - 7) & (index < test_boundary)]
        test = df.loc[index >= test_boundary - 7]

        self.set_scalers(train)

        return (self.transform_inputs(data) for data in [train, valid, test])

    def set_scalers(self, df):
        """Calibrates scalers using the data supplied.

        Args:
          df: Data to use to calibrate scalers.
        """
        print('Setting scalers with training data...')

        column_definitions = self.get_column_definition()
        id_column = utils.get_single_col_by_input_type(InputTypes.ID,
                                                       column_definitions)
        target_column = utils.get_single_col_by_input_type(InputTypes.TARGET,
                                                           column_definitions)

        # Extract identifiers in case required
        self.identifiers = list(df[id_column].unique())

        # Format real scalers
        real_inputs = utils.extract_cols_from_data_type(
            DataTypes.REAL_VALUED, column_definitions,
            {InputTypes.ID, InputTypes.TIME})

        data = df[real_inputs].values
        self._real_scalers = sklearn.preprocessing.StandardScaler().fit(data)
        self._target_scaler = sklearn.preprocessing.StandardScaler().fit(
            df[[target_column]].values)  # used for predictions

        # Format categorical scalers
        categorical_inputs = utils.extract_cols_from_data_type(
            DataTypes.CATEGORICAL, column_definitions,
            {InputTypes.ID, InputTypes.TIME})

        categorical_scalers = {}
        num_classes = []
        for col in categorical_inputs:
            # Set all to str so that we don't have mixed integer/string columns
            srs = df[col].apply(str)
            categorical_scalers[col] = sklearn.preprocessing.LabelEncoder().fit(
              srs.values)
            num_classes.append(srs.nunique())

        # Set categorical scaler outputs
        self._cat_scalers = categorical_scalers
        self._num_classes_per_cat_input = num_classes

    def transform_inputs(self, df):
        """Performs feature transformations.

        This includes both feature engineering, preprocessing and normalisation.

        Args:
          df: Data frame to transform.

        Returns:
          Transformed data frame.

        """
        output = df.copy()

        if self._real_scalers is None and self._cat_scalers is None:
            raise ValueError('Scalers have not been set!')

        column_definitions = self.get_column_definition()

        real_inputs = utils.extract_cols_from_data_type(
            DataTypes.REAL_VALUED, column_definitions,
            {InputTypes.ID, InputTypes.TIME})
        categorical_inputs = utils.extract_cols_from_data_type(
            DataTypes.CATEGORICAL, column_definitions,
            {InputTypes.ID, InputTypes.TIME})

        # Format real inputs
        output[real_inputs] = self._real_scalers.transform(df[real_inputs].values)

        # Format categorical inputs
        for col in categorical_inputs:
            string_df = df[col].apply(str)
            output[col] = self._cat_scalers[col].transform(string_df)

        return output

    def format_predictions(self, predictions):
        """Reverts any normalisation to give predictions in original scale.

        Args:
          predictions: Dataframe of model predictions.

        Returns:
          Data frame of unnormalised predictions.
        """
        output = predictions.copy()

        column_names = predictions.columns

        for col in column_names:
            if col not in {'forecast_time', 'identifier'}:
                output[col] = self._target_scaler.inverse_transform(predictions[col])

        return output
    
    
    def get_fixed_params(self):
        """Returns fixed model parameters for experiments."""

        fixed_params = {
            'total_time_steps': 8*24,     # Total width of the Temporal Fusion Decoder
            'num_encoder_steps': 7*24,    # Length of LSTM decoder (ie. # historical inputs)
            'num_epochs': 100,            # Max number of epochs for training 
            'early_stopping_patience': 5, # Early stopping threshold for # iterations with no loss improvement
            'multiprocessing_workers': 5  # Number of multi-processing workers
        }

        return fixed_params

# %% [markdown]
# ###  Tranining and Evaluating the TFT

# %%
# Create a data formatter 
data_formatter = TrafficFormatter()

# Split data 
train, valid, test = data_formatter.split_data(df)

data_params = data_formatter.get_experiment_params()

# Model parameters for calibration
model_params = {'dropout_rate': 0.3,      # Dropout discard rate
                'hidden_layer_size': 320, # Internal state size of TFT
                'learning_rate': 0.001,   # ADAM initial learning rate
                'minibatch_size': 128,    # Minibatch size for training
                'max_gradient_norm': 100.,# Max norm for gradient clipping
                'num_heads': 4,           # Number of heads for multi-head attention
                'stack_size': 1           # Number of stacks (default 1 for interpretability)
               }

# Folder to save network weights during training.
model_folder = os.path.join(output_folder, 'saved_models', 'traffic', 'fixed')
model_params['model_folder'] = model_folder

model_params.update(data_params)
# Out:
# Formatting train-valid-test splits.
# Setting scalers with training data...

# %%
from libs.tft_model import TemporalFusionTransformer

# Specify GPU usage
tf_config = utils.get_default_tensorflow_config(tf_device="gpu", gpu_id=0)
# Out:
# Selecting GPU ID=0

# %%
tf.compat.v1.reset_default_graph()
with tf.Graph().as_default(), tf.compat.v1.Session(config=tf_config) as sess:

    tf.compat.v1.keras.backend.set_session(sess)
    
    # Create a TFT model
    model = TemporalFusionTransformer(model_params, 
                                    use_cudnn=False) # Run model on GPU using CuDNNLSTM cells

    """
    # Sample data into minibatches for training
    if not model.training_data_cached():
        model.cache_batched_data(train, "train", num_samples=50)
        model.cache_batched_data(valid, "valid", num_samples=10)

    # Train and save model
    # model.fit()
    # model.save(model_folder)
    """
# Out:
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# # hidden_layer_size = 320
# # learning_rate = 0.001
# # minibatch_size = 128
# # max_gradient_norm = 100.0
# # num_heads = 4
# # stack_size = 1
# # model_folder = /content/drive/My Drive/TFT for TSF/tft/outputs/saved_models/traffic/fixed
# # total_time_steps = 192
# # num_encoder_steps = 168
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.TIME: 5>), ('values', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('time_on_day', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('categorical_id', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# # input_size = 5
# # output_size = 1
# # category_counts = [963]
# # input_obs_loc = [0]
# # static_input_loc = [4]
# # known_regular_inputs = [1, 2, 3]
# # known_categorical_inputs = [0]
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 5)]     0
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 192, 320)     308160      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 320)]        0           sequential[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 320)          102720      flatten[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation (Activation)         (None, 320)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 320)       102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 320)          102720      activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 320)       0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 320)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 320)       102720      activation_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            321         dropout[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            321         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 320)       0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            321         flatten[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1)            0           dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 320)       102720      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 320)       102720      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dense_4[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1, 320)       0           dense_11[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 1)            2           add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 320)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 1, 320)       640         add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 1)]       0           activation_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1, 320)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 320)]        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 320)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 4)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 320)          102720      activation_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 320)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 192, 320)     640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 192, 320)     640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 192, 320)     640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 192, 320)     640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 320)          102720      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 320)          102720      dropout_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 320, 3) 0           time_distributed_1[0][0]
#                                                                  time_distributed_2[0][0]
#                                                                  time_distributed_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 320, 1) 0           time_distributed[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 320)          0           dense_15[0][0]
#                                                                  dense_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320, 3) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320, 1) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320, 4) 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 320)          640         add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 1280)]  0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 3)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 168, 320)     409920      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 960)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320)]   0           time_distributed_5[0][0]
#                                                                  time_distributed_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 24, 320)      307520      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 320)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 168, 320)     102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 168, 320)     102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 168, 320)     102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 168, 320)     102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           time_distributed_27[0][0]
#                                                                  time_distributed_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 168, 320)     102720      activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 320)     0           time_distributed_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 320)     0           time_distributed_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 320)     0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 320)     0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 24, 320)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 168, 320)     0           time_distributed_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 168, 320)     102720      activation_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 168, 320)     102720      activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 168, 320)     102720      activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 168, 320)     102720      activation_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 24, 320)      102720      activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 320)      0           time_distributed_32[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 320)      0           time_distributed_36[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 320)      0           time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 168, 4)       1284        dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 168, 4)       1284        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 168, 320)     0           time_distributed_11[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 168, 320)     0           time_distributed_15[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 168, 320)     0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 168, 320)     0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 24, 320)      0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 24, 320)      102720      activation_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 24, 320)      102720      activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 24, 320)      102720      activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 168, 4)       5124        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 4)       0           time_distributed_8[0][0]
#                                                                  time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 168, 320)     102720      dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 168, 320)     102720      dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 168, 320)     102720      dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 168, 320)     102720      dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 168, 320)     102720      dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 168, 320)     102720      dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 168, 320)     102720      dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 168, 320)     102720      dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 320)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 320)          0           dense_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 24, 3)        963         dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 24, 3)        963         dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 24, 320)      0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 24, 320)      0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 24, 320)      0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 168, 4)       0           time_distributed_4[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 320)     0           time_distributed_12[0][0]
#                                                                  time_distributed_13[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 320)     0           time_distributed_16[0][0]
#                                                                  time_distributed_17[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 168, 320)     0           time_distributed_20[0][0]
#                                                                  time_distributed_21[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 168, 320)     0           time_distributed_24[0][0]
#                                                                  time_distributed_25[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 320)          102720      activation_5[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 320)          102720      activation_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 24, 3)        2883        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 24, 3)        0           time_distributed_30[0][0]
#                                                                  time_distributed_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 24, 320)      102720      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 24, 320)      102720      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 24, 320)      102720      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 24, 320)      102720      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 24, 320)      102720      dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 24, 320)      102720      dropout_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 168, 4)       8           add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 168, 320)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 168, 320)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 168, 320)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 168, 320)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 320)          0           dense_22[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 320)          0           dense_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 24, 3)        0           time_distributed_26[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 24, 320)      0           time_distributed_34[0][0]
#                                                                  time_distributed_35[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 24, 320)      0           time_distributed_38[0][0]
#                                                                  time_distributed_39[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 24, 320)      0           time_distributed_42[0][0]
#                                                                  time_distributed_43[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 4)       0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 168, 320)     640         add_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 168, 320)     640         add_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 168, 320)     640         add_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 168, 320)     640         add_10[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 320)          102720      dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 320)          102720      dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 320)          102720      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 320)          102720      dropout_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 24, 3)        6           add_11[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 24, 320)      0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 24, 320)      0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 24, 320)      0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 1, 4)]  0           activation_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320, 4) 0           layer_normalization_7[0][0]
#                                                                  layer_normalization_8[0][0]
#                                                                  layer_normalization_9[0][0]
#                                                                  layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 320)          0           dense_23[0][0]
#                                                                  dense_24[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 320)          0           dense_27[0][0]
#                                                                  dense_28[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 3)        0           layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 24, 320)      640         add_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 24, 320)      640         add_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 24, 320)      640         add_14[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 168, 320, 4)  0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 1, 3)]   0           activation_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 3)] 0           layer_normalization_12[0][0]
#                                                                  layer_normalization_13[0][0]
#                                                                  layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 320)]   0           multiply_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 320)          640         add_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 320)          640         add_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 24, 320, 3)   0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 168, 320), ( 820480      tf_op_layer_TemporalFusionTransfo
#                                                                  layer_normalization_4[0][0]
#                                                                  layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           multiply_17[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 320)          0           dense_17[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 24, 320)      820480      tf_op_layer_TemporalFusionTransfo
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 320)          102720      activation_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 320)]   0           lstm[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 320)          0           dense_18[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 192, 320)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 320)          102720      dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 320)          102720      dropout_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 192, 320)     102720      dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 192, 320)     102720      dropout_15[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 320)          0           dense_19[0][0]
#                                                                  dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 192, 320)     0           time_distributed_44[0][0]
#                                                                  time_distributed_45[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 320)]   0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 192, 320)     0           multiply_18[0][0]
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 320)          640         add_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 192, 320)     640         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 192, 320)     102720      layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 320)]   0           time_distributed_46[0][0]
#                                                                  time_distributed_47[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 192, 320)     0           tf_op_layer_TemporalFusionTransfo
# ...
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(1,)]               0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(1,)]               0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(2,)]               0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None)]       0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 192, 192)     0           dense_77[0][0]
#                                                                  dense_78[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 192, 192)     0           dense_79[0][0]
#                                                                  dense_80[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 192, 192)     0           dense_81[0][0]
#                                                                  dense_82[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 192, 192)     0           dense_83[0][0]
#                                                                  dense_84[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 192, 192)     0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 192, 192)     0           lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 192, 192)     0           lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 192, 192)     0           lambda_9[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 192, 192)     0           add_17[0][0]
#                                                                  add_18[0][0]
#                                                                  add_19[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 192, 192)     0           activation_19[0][0]
#                                                                  activation_19[1][0]
#                                                                  activation_19[2][0]
#                                                                  activation_19[3][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 192, 80)      25600       layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 192, 80)      0           dropout_17[0][0]
#                                                                  dense_76[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 192, 80)      0           dropout_17[1][0]
#                                                                  dense_76[1][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 192, 80)      0           dropout_17[2][0]
#                                                                  dense_76[2][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 192, 80)      0           dropout_17[3][0]
#                                                                  dense_76[3][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 192, 80)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 192, 80)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 192, 80)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 192, 80)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(4, None, 192, 80)] 0           dropout_18[0][0]
#                                                                  dropout_19[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 80)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 192, 320)     25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 192, 320)     0           dense_85[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 192, 320)     0           dropout_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 192, 320)     102720      dropout_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 192, 320)     102720      dropout_23[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 192, 320)     0           time_distributed_51[0][0]
#                                                                  time_distributed_52[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 192, 320)     0           multiply_20[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 192, 320)     640         add_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 192, 320)     102720      layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 192, 320)     0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 192, 320)     102720      activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 192, 320)     0           time_distributed_54[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 192, 320)     102720      dropout_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 192, 320)     102720      dropout_24[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 192, 320)     0           time_distributed_55[0][0]
#                                                                  time_distributed_56[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 192, 320)     0           layer_normalization_17[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 192, 320)     640         add_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 192, 320)     102720      layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 192, 320)     102720      layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 192, 320)     0           time_distributed_57[0][0]
#                                                                  time_distributed_58[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 192, 320)     0           multiply_22[0][0]
#                                                                  layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 192, 320)     640         add_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 24, 3)        963         tf_op_layer_TemporalFusionTransfo
# ==================================================================================================
# Total params: 10,037,163
# Trainable params: 10,037,163
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
test.iloc[0:1000, :].shape
# Out:
# (1000, 11)

# %% [markdown]
# ## Evaluation and Prediction using the pre-trained model

# %%
tf.reset_default_graph()
with tf.Graph().as_default(), tf.Session(config=tf_config) as sess:

    tf.keras.backend.set_session(sess)
    
    # Create a new model & load weights
    model = TemporalFusionTransformer(model_params, 
                                    use_cudnn=False)
    model.load(model_folder)
    
    # Make forecasts
    output_map = model.predict(test.iloc[0:1000, :], return_targets=True)

    targets = data_formatter.format_predictions(output_map["targets"])

    # Format predictions
    p50_forecast = data_formatter.format_predictions(output_map["p50"])
    p90_forecast = data_formatter.format_predictions(output_map["p90"])

    def extract_numerical_data(data):
        """Strips out forecast time and identifier columns."""
        return data[[
          col for col in data.columns
          if col not in {"forecast_time", "identifier"}
        ]]

    # Compute Losses
    p50_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p50_forecast),
        0.5)
    p90_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p90_forecast),
        0.9)
# Out:
# Streaming output truncated to the last 5000 lines.
#   0.07739288  0.03955202 -0.09887701  0.00948162 -0.21879433 -0.04601607
#   0.09287839  0.00809182  0.01805272 -0.06296187 -0.14795761 -0.12241773
#   0.05603879 -0.04685853 -0.15165152  0.01709236  0.09165497  0.06416281
#  -0.16928847  0.11892383  0.17206778  0.11610553  0.02112488 -0.10520112
#   0.05723071 -0.11360922 -0.11735214 -0.1713498  -0.06356564 -0.08091141
#  -0.10178725 -0.1810047  -0.01998587  0.07070092  0.03897497 -0.2733673
#   0.08302445 -0.0187608  -0.11678708 -0.06044887 -0.04079724 -0.07879058
#   0.0324606   0.03260928 -0.23869754 -0.10700552  0.03089817 -0.11465174
#  -0.26881588 -0.06532943  0.05993899 -0.11228778 -0.03248532 -0.06626307
#   0.00819984 -0.01801739 -0.01816012 -0.15278673 -0.08721187  0.02464575
#  -0.06214429  0.07527794  0.1145146  -0.10380276  0.04638393  0.04546439
#   0.12673347 -0.21823458 -0.0522074   0.00416751 -0.07782676 -0.17062712
#   0.11549252 -0.04223298 -0.11037263 -0.11125893 -0.17521772  0.17460798
#  -0.02672865 -0.09595949  0.05041673 -0.12357135 -0.17450011  0.04561142
#   0.00650241  0.00556605  0.03457773  0.01770626 -0.07977264 -0.08188318
#   0.05237868  0.05506132  0.12877576 -0.00244362 -0.08980609 -0.12206939
#  -0.10209474  0.08485442 -0.03549483  0.12828387 -0.05180323 -0.17291975
#   0.0357823  -0.11835668 -0.11388373 -0.22327875  0.02101346 -0.06336533
#  -0.01054211 -0.14128187 -0.10107057 -0.01401549  0.0059033   0.03084135
#  -0.09149726  0.05712918 -0.0512475  -0.11428411  0.08723294  0.05614172
#  -0.23343228 -0.11175206  0.05071843  0.11117843  0.04158537 -0.03970167
#  -0.0799962  -0.05502314  0.02948719 -0.06525363  0.0149169  -0.21590437
#   0.10179529  0.24756184  0.05583803  0.12586114 -0.11783655  0.03322801
#  -0.0724206  -0.09531142 -0.09056565 -0.21357654  0.04592644 -0.09091005
#   0.00397805 -0.01105742  0.14612211  0.06744258  0.07776758  0.10047901
#   0.06423461  0.0121227  -0.2082559   0.00289812 -0.09906945 -0.06546322
#  -0.11828617 -0.02833196  0.03352812 -0.03022733  0.16977373 -0.100423
#  -0.26408723 -0.12275594 -0.03838275 -0.01647095 -0.17633829  0.00409001
#  -0.09130009 -0.13287216  0.13418913  0.09631152 -0.10265508  0.0596562
#   0.22800818 -0.21461381 -0.05921035 -0.03613117 -0.0953965  -0.09976438
#  -0.03528607 -0.07402509  0.05598998  0.01977192 -0.0027526  -0.02700995
#   0.01702876 -0.02803829]
# tensor_name:  TemporalFusionTransformer/time_distributed_7/kernel
# [[ 0.00339465 -0.02896547  0.02367708 ...  0.03708607 -0.174317
#   -0.02012458]
#  [ 0.17354418 -0.00341989  0.0483192  ... -0.03526146 -0.03008212
#    0.11839925]
#  [-0.11796481  0.14563228 -0.11961184 ... -0.04733302 -0.03807362
#   -0.00679476]
#  ...
#  [-0.20428239 -0.01649465 -0.04612704 ...  0.05424723  0.10740857
#   -0.08346122]
#  [ 0.06579497 -0.01633163  0.06400862 ... -0.10423444 -0.08839974
#   -0.07339428]
#  [ 0.12471645 -0.07592107  0.01551002 ...  0.03704106 -0.00905521
#    0.11257059]]
# tensor_name:  TemporalFusionTransformer/time_distributed_8/bias
# [-0.04701209  0.00148097 -0.11747351  0.03329137]
# tensor_name:  TemporalFusionTransformer/time_distributed_8/kernel
# [[-0.10423066  0.17684384 -0.09672177 -0.00354449]
#  [-0.04116327  0.03203323 -0.05358158  0.02717509]
#  [-0.11051279  0.05690763  0.00057331 -0.00530259]
#  ...
#  [ 0.05302742  0.11612113 -0.05111092  0.04725567]
#  [ 0.04587377  0.02222624 -0.14881343  0.11474876]
#  [-0.08107362 -0.09999028 -0.02002394  0.01254593]]
# tensor_name:  TemporalFusionTransformer/time_distributed_9/bias
# [-0.0567195   0.00561951  0.00282865 -0.00630225]
# tensor_name:  TemporalFusionTransformer/time_distributed_9/kernel
# [[-0.05181442 -0.11637975 -0.01363725 -0.11005688]
#  [ 0.08509672 -0.01171799  0.07820542  0.16966958]
#  [-0.07792512 -0.06201782 -0.02763592 -0.21692203]
#  ...
#  [-0.15420642  0.02917676 -0.05443501 -0.00335173]
#  [-0.05188403 -0.04046123  0.16283438  0.16552587]
#  [-0.10596724  0.10886751  0.05616366  0.15994453]]
# # Total number of params: 10037163
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/TFT for TSF/tft/outputs/saved_models/traffic/fixed/TemporalFusionTransformer.ckpt
# Done.

# %%
p50_loss
# Out:
# t+0     0.065809
# t+1     0.076967
# t+2     0.082269
# t+3     0.084646
# t+4     0.086255
# t+5     0.084886
# t+6     0.085092
# t+7     0.086312
# t+8     0.086987
# t+9     0.085360
# t+10    0.085060
# t+11    0.084944
# t+12    0.084937
# t+13    0.085444
# t+14    0.085260
# t+15    0.084837
# t+16    0.086007
# t+17    0.087363
# t+18    0.089672
# t+19    0.091522
# t+20    0.092482
# t+21    0.092408
# t+22    0.093196
# t+23    0.092788
# dtype: float64

# %%
p90_loss
# Out:
# t+0     0.032772
# t+1     0.036503
# t+2     0.044857
# t+3     0.041505
# t+4     0.040980
# t+5     0.046467
# t+6     0.048682
# t+7     0.048603
# t+8     0.050389
# t+9     0.049548
# t+10    0.048932
# t+11    0.048150
# t+12    0.047965
# t+13    0.048577
# t+14    0.050436
# t+15    0.052087
# t+16    0.054139
# t+17    0.057625
# t+18    0.061893
# t+19    0.062612
# t+20    0.062635
# t+21    0.062864
# t+22    0.063323
# t+23    0.064972
# dtype: float64
